# %% [markdown]
# # Lab : Python Basics

# %% [markdown]
# ## 1.1 Sub heading

# %% [markdown]
# ### 1.1.1 Hello World

# %% [markdown]
# The first Python program generates "hello world"

# %%
print('hello world') # Generate "Hello world".
print("hello world") # Generate "Hello world".
# Out:
# hello world
# hello world

# %%
print(True+False)
# Out:
# 1

# %% [markdown]
# An example of power (**)

# %%
2**10
# Out:
# 1024

# %% [markdown]
# ## 1.1.3 Data Type: String

# %% [markdown]
# Step 1 Basic opereations on strings:

# %%
s = 'python'
len(s)
# Out:
# 6

# %%
print(s[0],s[1],s[2])
# Out:
# p y t

# %% [markdown]
# Step 2 immutability of Strings

# %%
" ".join(['today','is','a','good','day','to study'])
# Out:
# 'today is a good day to study'

# %%
list1 = [12, 45, 32, 55]

# %%
list1.sort()

# %%
print(list1)
# Out:
# [12, 32, 45, 55]

# %% [markdown]
# An example of sorting numbers in a list
#
# For writing latex
#
# $$
# \omega = 2\pi f \\
# f = \frac{c}{\lambda}\\
# \lambda_0=\theta^2+\delta\\
# \Delta\lambda = \frac{1}{\lambda^2}
# $$

# %%
list1.reverse()

# %%
print(list1)
# Out:
# [55, 45, 32, 12]

# %%
# dictionaries
x = {'food':'hamburger','quantity':1}
x
# Out:
# {'food': 'hamburger', 'quantity': 1}

# %%
x['food']
# Out:
# 'hamburger'

# %%
x.get('food')
# Out:
# 'hamburger'

# %%
x = dict(food='hamburger',quantity=1)
x = dict([('food','hamburger')])

# %%
x.clear()

# %%
x
# Out:
# {}

# %% [markdown]
# # An introduction to Set in Python

# %% [markdown]
# There is no index in set

# %%
sample_sets = {"Prince","Techs"}

# %%
sample_sets
# Out:
# {'Prince', 'Techs'}

# %% [markdown]
# We add another data

# %%
sample_sets.add("Data")

# %%
sample_sets
# Out:
# {'Data', 'Prince', 'Techs'}

# %%
sample_sets.remove("Data")

# %%
sample_sets
# Out:
# {'Prince', 'Techs'}

# %% [markdown]
# Deep Copy and Shallow Copy

# %%
# Determine the entered score.
# input(): Receive input data.
score = input("Please enter your score.") # The input function receives input, which is a string.
score = float(score) # Convert the score to a number.
# try: except Exception: … is a Python statement used to capture exceptions. If an error occurs in the statement in try, the statement in except is executed.
try:
    if 100>=score>=90: # Check whether the entered value is greater than the score of a level.
        print("Excellent") # Generate the level when conditions are met.
    elif 90 > score >= 80:
        print("Good")
    elif 80>score>0:
        print("Medium")
    else:
        print("Bad")
except Exception:
    print("Enter a correct score.")
# Out:
# Please enter your score.1
# Medium

# %% [markdown]
# Loop statement

# %%
for i in range(1,10): # Define the outer loop.
    for j in range(1,i+1):# Define the inner loop.
        # Format the output string to align the generated result. The end attribute is set to /n by default.
        print("%d*%d=%2d"%(i,j,i*j), end=" ")
        print()
# Out:
# 1*1= 1
# 2*1= 2
# 2*2= 4
# 3*1= 3
# 3*2= 6
# 3*3= 9
# 4*1= 4
# 4*2= 8
# 4*3=12
# 4*4=16
# 5*1= 5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 6*1= 6
# 6*2=12
# 6*3=18
# 6*4=24
# 6*5=30
# 6*6=36
# 7*1= 7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 8*1= 8
# 8*2=16
# 8*3=24
# 8*4=32
# 8*5=40
# 8*6=48
# 8*7=56
# 8*8=64
# 9*1= 9
# 9*2=18
# 9*3=27
# 9*4=36
# 9*5=45
# 9*6=54
# 9*7=63
# 9*8=72
# 9*9=81

# %%
def fibs(num): # Position parameter.
    result = [0,1] # Create a list to store the sequence value.
    for i in range(2,num): # Cycle num-2 times.
        a = result[i-1] + result[i-2]
        result.append(a) # Append the value to the list.
    return result # Return the list.
fibs(5)
# Out:
# [0, 1, 1, 2, 3]

# %%
def hello(greeting='hello',name='world'): # Default parameters.
    print('%s, %s!' % (greeting, name)) # Format the output.
hello() # hello，world Default parameter.
hello('Greetings') # Greetings，world Position parameter.
hello ('Greetings', 'universe') # Greetings, universe Position parameter.
hello (name= 'Gumby') # hello, Gumby Keyword parameter.
# Out:
# hello, world!
# Greetings, world!
# Greetings, universe!
# hello, Gumby!
